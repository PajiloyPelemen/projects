# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Евгений :)  Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез,  интерпретации значения p-value - можно повторить недели через две </b>(для профилактики :) )
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил бонус

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет , вот мой вопрос ...
#        Вроде сделал все, что ты писал, кроме графиков. Не понял как добавить раздел "другое" (вроде бы было в начале курса но найти не смог) и общее название. + не уверен в методе замены для ESRB. Остальное вроде норм

# %% [markdown]
# Привет, спасибо за подсказки, добавил раздел другое для платформ и жанров, но теперь вывод графиков в одном окошке вообще не получается, что странно. Подправил ESRB, но в Японии слишком много игр без рейтинга. Пока не знаю что делать (либо вручную проставить несколько топ игр по продажам Японии без рейтинга (но как то неприкольно), либо нашел какой-то датасет https://www.kaggle.com/datasets/imohtn/video-games-rating-by-esrb?resource=download с рейтингами игр, но не уверен могу ли я непонятно откуда брать инфу. Хотя, наверное ее легко проверить если что. Остально все тоже вроде бы исправил.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Евгений :) Спасибо за доработки
#
# Критические ❌ комментарии:
#
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах (ящики с усами)
#  + оценить прибыльность жанров на диаграмме размаха (ящики с усами)
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value __для второго стат. теста — для тренировки навыка__
#
# новые подсказки добавил
#
#         Подправил ESRB, но в Японии слишком много игр без рейтинга. Пока не знаю что делать (либо вручную проставить несколько топ игр по продажам Японии без рейтинга (но как то неприкольно),
#
# можно отбросить сомнения — кому принадлежит организация, которая выдает рейтинги ESRB?

# %% [markdown]
# Привет, спасбо за подсказки, очень помогли. Все подправил и проанализировал (см Анализ жанров и Расшифровка p-value)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Привет, Евгений :) Спасибо за доработки
#
# Критические ❌ комментарии:
#
#  + заполнение пропусков в рейтингах ESRB
#  + поправить перечень перспективных платформ
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + оценить прибыльность жанров на диаграмме размаха
#  + создать выборку в подразделе портретов из ТОП-5 и категории «другие»
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value
#
# подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# # Закономерности, определяющие успешность игр для магазина "Стримчик"

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту
#
# а подробности выполнения проекта дадут возможность вспомнить через полгода — что мы тут делали

# %% [markdown]
# Цель:выявить определяющие успешность игры закономерности.
# Задачи:
# 1. Открыть файл
# 2. Подготовить данные
# 3. Провести исследовательский анализ данных
# 4. Составить портрет пользователя каждого региона
# 5.  Проверить гипотезы
# 6. Сделать вывод

# %% [markdown]
# ## check

# %%
import pandas as pd
from scipy import stats as st
import warnings
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
data = pd.read_csv("/datasets/games.csv")
data.head(5)
pd.set_option("display.precision", 2)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера </b></font>
# <br />
# <font size="3", color = "black">
# <br />   Кажется весь код на проекте запускался вручную ..., строка кода 47 в самом начале проекта ...
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# Проверить работоспособность кода — можно нажав на панели Jupiter Hub Kernel и Restart & Run All (см скриншот ниже).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Обзор данных

# %%
data.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
#data.columns = ["name","platform","year_of_release","genre","na_sales","eu_sales","jp_sales","other_sales","critic_score","user_score","rating"]
#data = data.rename(columns={"Name":"name","Platform":"platform","Year_of_Release":"year_of_release","Genre":"genre",
#             "NA_sales":"na_sales","EU_sales":"eu_sales","JP_sales":"jp_sales","Other_sales":"other_sales",
#             "Critic_Score":"critic_score","User_Score":"user_score","Rating":"rating"},errors="raise")
data.columns = data.columns.str.lower()
data.head(5)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Тебе удалось переименовать столбцы, хотя и не оптимальным методом.
#
# Для этих целей лучше подойдет метод rename(): он принимает словарь со старыми и новыми названиями столбцов. Это позволяет при необходимости переименовать только часть столбцов или передать их в произвольном порядке, а также избежать ошибок, если поменяется порядок колонок в датафрейме
#
# __или другим способом, который не будет зависеть от очередности колонок в датафрейме__

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />можно
#
#     games.columns = games.columns.str.lower()
#
# в этом случае мы не ошибемся с порядком  колонок

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?

# %%
# check
# пропущенные значения бары

def pass_value_barh1(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = 0, legend = False, fontsize = 16,grid=True) #Немного косой текст
            .set_title('Пример', fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh1(data)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, к вопросу сетки вернемся на втором модуле
#
# Можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100
#
#         plt.xlim(0, 100)

# %% [markdown]
# ## Обработка пропусков и дубликатов

# %%
data["user_score"].unique()  #tbd = to be decided/determined (Что странно, стоит и на старых играх)  
data.loc[data["user_score"] == "tbd","user_score"] = None
data["user_score"] = data["user_score"].astype('float64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Оценка от пользователей в виде числа полезнее - можно сортировать и тд. tbd - сменил на пропуск, по сути то же самое. Год можно оставить в виде числа

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
for i in range(1980,2017):
    data.loc[data["year_of_release"]==i,"year_of_release"]=int(i)
data["year_of_release"].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %%
display(data.loc[data["name"].isna(),:] )# По сути бесполезно
data = data.dropna(subset=["name"])
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %%
display(data.loc[data["year_of_release"].isna(),:]["platform"].unique()) #Вместо пустого значения поставить год выхода консоли?
#еще можно из названия год достать
# Out:
# array(['PS2', 'Wii', '2600', 'X360', 'GBA', 'PC', 'PS3', 'PS', 'PSP',
#        'XB', 'GB', 'DS', 'GC', '3DS', 'N64', 'PSV'], dtype=object)

# %% [markdown]
# Сначала попробую достать год выпуска из названия

# %%
for name in data.loc[data["year_of_release"].isna(),"name"]:
    year = []
    for i in name:
        if i.isdigit():
            year.append(i)
    year = "".join(year)
    if year != "":
        if 1950<int(year) < 2020:
            data.loc[data["name"] == name,"year_of_release"] = int(year)
            display(data.loc[data["name"] == name,:])
data["year_of_release"].sort_values().unique()
# Out:
#                  name platform  year_of_release   genre  na_sales  eu_sales  \
# 183   Madden NFL 2004      PS2           2004.0  Sports      4.26      0.26
# 1881  Madden NFL 2004       XB           2004.0  Sports      1.02      0.02
# 3889  Madden NFL 2004       GC           2004.0  Sports      0.40      0.10
# 5708  Madden NFL 2004      GBA           2004.0  Sports      0.22      0.08
#
#       jp_sales  other_sales  critic_score  user_score rating
# 183       0.01         0.71          94.0         8.5      E
# 1881      0.00         0.05          92.0         8.3      E
# 3889      0.00         0.01          94.0         7.7      E
# 5708      0.00         0.01          70.0         6.6      E
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 377    FIFA Soccer 2004      PS2           2004.0  Sports      0.59      2.36
# 2606   FIFA Soccer 2004       XB           2004.0  Sports      0.24      0.49
# ...

# %%
data.isna().sum() #269 - 251 = 18 ну, такое.
# Out:
# name                  0
# platform              0
# year_of_release     251
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# dtype: int64

# %% [markdown]
# Вместо пустого значения поставить средний год для этой консоли

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />проверим корректность алгоритма заполнения пропусков

# %%
# check
# жизненный срок платформы

years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)
# Out:
#              min     max  years_of_life
# platform
# 2600      1980.0  1989.0            9.0
# 3DO       1994.0  1995.0            1.0
# 3DS       2011.0  2016.0            5.0
# DC        1998.0  2008.0           10.0
# DS        1985.0  2013.0           28.0
# GB        1988.0  2001.0           13.0
# GBA       2000.0  2007.0            7.0
# GC        2001.0  2007.0            6.0
# GEN       1990.0  1994.0            4.0
# GG        1992.0  1992.0            0.0
# N64       1996.0  2002.0            6.0
# NES       1983.0  1994.0           11.0
# NG        1993.0  1996.0            3.0
# PC        1985.0  2016.0           31.0
# PCFX      1996.0  1996.0            0.0
# PS        1994.0  2003.0            9.0
# PS2       2000.0  2011.0           11.0
# PS3       2006.0  2016.0           10.0
# PS4       2013.0  2016.0            3.0
# PSP       2004.0  2015.0           11.0
# PSV       2011.0  2016.0            5.0
# SAT       1994.0  1999.0            5.0
# ...

# %% [markdown]
# .mean() Почему то не сработал, взял медиану

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.  ⬇⬇⬇
#
# </div>

# %%
#for platform in ['PS2', 'Wii', '2600', 'X360', 'GBA', 'PC', 'PS3', 'PS', 'PSP','XB', 'GB', 'DS', 'GC', '3DS', 'N64', 'PSV']:
#    data.loc[data["year_of_release"].isna(),"year_of_release"] = data.loc[data["platform"] == platform,"year_of_release"].median()
data = data.dropna(subset=["year_of_release"])

# %%
# check
# жизненный срок платформы

years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life

# years_of_life.sort_values(by = 'years_of_life', ascending = False)
# Out:
#              min     max  years_of_life
# platform
# 2600      1980.0  1989.0            9.0
# 3DO       1994.0  1995.0            1.0
# 3DS       2011.0  2016.0            5.0
# DC        1998.0  2008.0           10.0
# DS        1985.0  2013.0           28.0
# GB        1988.0  2001.0           13.0
# GBA       2000.0  2007.0            7.0
# GC        2001.0  2007.0            6.0
# GEN       1990.0  1994.0            4.0
# GG        1992.0  1992.0            0.0
# N64       1996.0  2002.0            6.0
# NES       1983.0  1994.0           11.0
# NG        1993.0  1996.0            3.0
# PC        1985.0  2016.0           31.0
# PCFX      1996.0  1996.0            0.0
# PS        1994.0  2003.0            9.0
# PS2       2000.0  2011.0           11.0
# PS3       2006.0  2016.0           10.0
# PS4       2013.0  2016.0            3.0
# PSP       2004.0  2015.0           11.0
# PSV       2011.0  2016.0            5.0
# SAT       1994.0  1999.0            5.0
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы внесли искажения в колонку год выпуска игры, которые приводят к ошибкам при определении срока жизни платформ
#
# Стоит посмотреть на платформы, к которым относятся пропуски, __и с легкостью расстанешься с ними ...__
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8466
# user_score         8988
# rating             6682
# dtype: int64

# %% [markdown]
# Остальные пропуски оставлю как есть - выбросить их нельзя (слишком много) но и заменить на что то не получиться. Они появляются из-за того что игры старые и оценок и рейтингов не было, слишком маленькие продажи и пользователи их не оценили, или ошибок

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера  </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />плюс  отсутствие ресурсов на сбор информации (время, деньги)

# %%
data["total_sales"] = data["na_sales"] + data["eu_sales"] +data["jp_sales"] + data["other_sales"] #na_sales	eu_sales	jp_sales	other_sales

# %%
for column in ["name","genre","platform","rating"]:
    data[column] = data[column].str.lower()

# %%
data = data.drop_duplicates(['name', 'platform', 'year_of_release'])

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Решение верное, перед удалением стоит посмотреть на записи — может это не дубликаты

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
data.query("rating.isna() and year_of_release > 2010 and total_sales > 1").head(10)
# Out:
#                                           name platform  year_of_release  \
# 31                   call of duty: black ops 3      ps4           2015.0
# 33                         pokemon x/pokemon y      3ds           2013.0
# 47   pokemon omega ruby/pokemon alpha sapphire      3ds           2014.0
# 72                                   minecraft     x360           2013.0
# 83             pokemon black 2/pokemon white 2       ds           2012.0
# 87                star wars battlefront (2015)      ps4           2015.0
# 96         super smash bros. for wii u and 3ds      3ds           2014.0
# 99                   call of duty: black ops 3     xone           2015.0
# 108                           pokemon sun/moon      3ds           2016.0
# 122                                    fifa 12      ps3           2011.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31        shooter      6.03      5.86      0.36         2.38           NaN
# ...

# %%
#data.loc[data.query("rating.isna() and genre == 'sports'").index,"rating"] ="e"

# %%
#data.loc[data.query("genre == 'shooter' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'shooter'").index,"rating"] ="m"

# %%
#data.loc[data.query("genre == 'shooter' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'misc' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()
#data.loc[data.query("rating.isna() and genre == 'misc'").index,"rating"] ="e10+"

# %%
#data.loc[data.query("genre == 'misc' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'role-playing' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'role-playing' and year_of_release > 2010 and total_sales > 1").index,["rating","total_sales"]].groupby("rating").sum().head(5)

# %% [markdown]
# Меня немного смущает, что покемон m получится, но и по количеству и по продажам РП получается m

# %%
#data.loc[data.query("rating.isna() and genre == 'role-playing' and 'pokemon' in name").index,"rating"] ="e"
#data.loc[data.query("rating.isna() and genre == 'role-playing'").index,"rating"] ="m"
#data.loc[data.query("genre == 'role-playing' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'fighting' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'fighting'").index,"rating"] ="t"
#data.loc[data.query("genre == 'fighting' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'simulation' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'simulation'").index,"rating"] ="e"
#data.loc[data.query("genre == 'simulation' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'racing' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'racing'").index,"rating"] ="e"
#data.loc[data.query("genre == 'racing' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'action' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'action'").index,"rating"] ="m"
#data.loc[data.query("genre == 'action' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'platform' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'platform'").index,"rating"] ="e"
#data.loc[data.query("genre == 'platform' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'puzzle' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'puzzle'").index,"rating"] ="e"
#data.loc[data.query("genre == 'puzzle' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("genre == 'adventure' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %%
#data.loc[data.query("rating.isna() and genre == 'adventure'").index,"rating"] ="m"
#data.loc[data.query("genre == 'adventure' and year_of_release > 2010 and total_sales > 1").index,"rating"].hist()

# %% [markdown]
# Делаем пометку для пустого рейтинга

# %%
data.loc[data.query("rating.isna()").index,"rating"] ="na"

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные. Стоит ли применять подобный способ заполнения пропусков. Сможем ли мы корректно учесть особенности выборки
#
#         Рейтинги для жанра Shooter
#         M       553
#         T       340
#         E10+     56
#         E        47
#
# Например, стоит ли все игры с пропусками для данного жанра переводить в рейтинг для  взрослых?
#
#         553 и 340 имеют примерно одинаковый вес ...
#
#
# Ты проделал большую работу по восстановлению пропусков. Но иногда пропуск сам по себе является ценной информацией. Для каких стран создавалась система ESRB? Будут ли стараться авторы игр для локального рынка других стран получить рейтинг ESRB?
#
# Оптимальнее на данном проекте использовать категорию «неизвестный рейтинг» ...

# %%
data.query("rating.isna() and year_of_release > 2010 and total_sales > 1").head(10)
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, total_sales]
# Index: []

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16461 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16461 non-null  object
#  1   platform         16461 non-null  object
#  2   year_of_release  16461 non-null  float64
#  3   genre            16461 non-null  object
#  4   na_sales         16461 non-null  float64
#  5   eu_sales         16461 non-null  float64
#  6   jp_sales         16461 non-null  float64
#  7   other_sales      16461 non-null  float64
#  8   critic_score     7995 non-null   float64
#  9   user_score       7473 non-null   float64
#  10  rating           16461 non-null  object
#  11  total_sales      16461 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 2.1+ MB

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг ESRB — категориальные данные, стоит внимательно взглянуть на содержимое и предложить чем заполнить пропуски, возможно это поможет найти необычные различия в поведении клиентов, допом можно подумать над сокращением количества категорий
#
# Т.к. записи с пропусками не учитываются при группировке данных, мы не сможем выявить реальный портрет клиента

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Датасет не проверен на наличие простых дубликатов
#
# __Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса__

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить вывод по результатам выполнения первого раздела проекта

# %% [markdown]
# Сделал обзор данных, добавил столбец для общих продаж, избавился от дубликатов и пропусков в столбцах Year of release и rating

# %% [markdown]
# ## check

# %% [markdown]
# ## Актуальные платформы

# %% [markdown]
# Сколько игр выпускались в разные годы? До 2000 года не интересно - слишком мало игр, слишком старые платформы

# %%
data.groupby("year_of_release")["name"].count()
# Out:
# year_of_release
# 1980.0       9
# 1981.0      46
# 1982.0      36
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1998.0     379
# 1999.0     338
# 2000.0     350
# 2001.0     477
# 2002.0     830
# 2003.0     779
# 2004.0     770
# 2005.0     941
# 2006.0    1008
# 2007.0    1198
# 2008.0    1426
# 2009.0    1430
# 2010.0    1255
# 2011.0    1137
# 2012.0     652
# 2013.0     547
# 2014.0     579
# 2015.0     606
# 2016.0     502
# Name: name, dtype: int64

# %%
data.groupby("platform")["total_sales"].sum().sort_values()
# Out:
# platform
# pcfx       0.03
# gg         0.04
# 3do        0.10
# tg16       0.16
# ws         1.42
# ng         1.44
# scd        1.86
# dc        15.95
# gen       28.35
# sat       33.59
# psv       53.81
# wiiu      82.19
# 2600      86.48
# xone     159.32
# gc       197.03
# snes     200.04
# n64      218.01
# nes      251.05
# xb       252.66
# gb       254.43
# pc       256.11
# 3ds      257.81
# psp      290.34
# gba      312.88
# ps4      314.14
# ps       727.58
# ds       802.79
# wii      891.18
# ps3      931.33
# x360     961.30
# ps2     1248.12
# Name: total_sales, dtype: float64

# %%
for platform in data["platform"].unique():
    data.loc[data["platform"]==platform,["year_of_release","total_sales"]].groupby("year_of_release").sum().plot(kind="bar",title=platform,y="total_sales")
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
data = data.drop(data.query("platform == 'ds' and year_of_release <= 2000").index)
data.loc[data["platform"]=="ds",["year_of_release","total_sales"]].groupby("year_of_release").sum().plot(kind="bar",title="ds",y="total_sales")
# Out:
# <AxesSubplot:title={'center':'ds'}, xlabel='year_of_release'>

# %% [markdown]
# 5 - 10 лет. Если консоль успешна, то она живет парралельно с новым поколением (xb360 есть продажи и в 2015 году)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# Актуальный период с 2013 года. Пик продаж для коснолей нового поколения будет как раз в 2017 году (4 года с момента релиза, такой же тайминг был у PS2 xb360, похожий был у ps3 и других популярных консолей)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит.

# %% [markdown]
# Потенциально прибыльные платформы - XOne и PS4 - продажи на них только растут, может быть повезет еще с PC - продажи на этой платформе постоянно меняются, но в прошлом году падали.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить перечень перспективных платформ
#
#
# даже  на падающих продажах можно заработать, когда объем составляет около 15-20 млн. копий, как например с 3DS

# %%
perspective_platforms = []
for platform in data["platform"].unique():
    test = data.loc[data["platform"]==platform,["year_of_release","total_sales"]].groupby("year_of_release").sum()
    if not test.loc[(test.index == 2015)&(test["total_sales"] > 20),:].empty:
        display(platform)
        display(test.loc[(test.index == 2015)&(test["total_sales"] > 20),:])
        perspective_platforms.append(platform)
# Out:
# 'ps4'
#                  total_sales
# year_of_release
# 2015.0                 118.9
# '3ds'
#                  total_sales
# year_of_release
# 2015.0                 27.78
# 'xone'
#                  total_sales
# year_of_release
# 2015.0                 60.14

# %%
perspective_platforms
# Out:
# ['ps4', '3ds', 'xone']

# %% [markdown]
# Платформы, которые в 2015 (за 2016 данные неполные) продали более 20 млн новых игр, и на которых можно заработать

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# X360 и PS3 уже исполнилось 11 лет и они с малой вероятностью станут перспективными или сохранят продажи в 2017 году
#
#         ['x360', 'ps3', 'ps4', '3ds', 'xone', 'wiiu']

# %%
new_data = data.loc[data["year_of_release"] >= 2013,:]

# %%
for platform in new_data["platform"].unique():
    new_data.loc[new_data["platform"]==platform,["year_of_release","total_sales"]].plot(kind="box",by="year_of_release",title=platform,y="total_sales")
    new_data.loc[new_data["platform"]==platform,["year_of_release","total_sales"]].plot(kind="box",by="year_of_release",title=platform,y="total_sales")
    plt.ylim(0,0.5)
    plt.show()

# %% [markdown]
# Игры продаются очень равномерно, редко когда есть выбросы в виде очень успешных годов.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Данный вид графиков не подойдет для зачета, мы не видим всю картину целиком, что не позволяет нам сравнить ящики всех платформ на одном виде ..., стоит воспользоваться советом ⬇⬇⬇ и перерисовать диаграммы

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Для более обоснованных выводов  стоит  перерисовать диаграмму размаха__, на актуальной выборке, не ограничивая перечень платформ:
#
# + используя параметр by, который позволит сравнить ящики всех жанров на одном виде,
# + в двух масштабах:
#     + 100%
#     + и где будет отображена только нижняя часть boxplot-ов
#
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки
#
# оставил ссылку на примеры
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html?highlight=boxplo#pandas.DataFrame.boxplot
#
#
# для изменения масштаба стоит применить ylim()
#
# https://matplotlib.org/stable/gallery/pyplots/axline.html#sphx-glr-gallery-pyplots-axline-py

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Не стоит суммировать продажи для отрисовки диаграммы размаха__ или каким-то иным образом группировать данные
#
# при помощи диаграммы размаха мы смотрим на распределение сырых данных и основные статистики, если мы суммируем продажи, мы изменяем выборку, а значит и все основные квартили и кол-во выбросов
#
#
# __Для более обоснованных выводов  стоит  перерисовать диаграмму размаха__, на актуальной выборке не суммируя продажи:
#
# + используя параметр by, который позволит сравнить ящики всех жанров на одном виде,
# + в двух масштабах:
#     + 100%
#     + и где будет отображена только нижняя часть boxplot-ов
#
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки
#
# оставил ссылку на примеры
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html?highlight=boxplo#pandas.DataFrame.boxplot
#
#
# для изменения масштаба стоит применить ylim()
#
# https://matplotlib.org/stable/gallery/pyplots/axline.html#sphx-glr-gallery-pyplots-axline-py

# %% [markdown]
# # example 1

# %% [markdown]
# #### example 3

# %% [markdown]
# ##### example 4

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %% [markdown]
# ## Зависимость продаж от отзывов

# %%
ps4_data=new_data.loc[new_data["platform"]=="ps4",:]
ps4_data.plot(kind="scatter",x="critic_score",y="total_sales")
ps4_data.plot(kind="scatter",x="user_score",y="total_sales")
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='total_sales'>

# %%
ps4_data.loc[:,["user_score","critic_score","total_sales"]].corr()
# Out:
#               user_score  critic_score  total_sales
# user_score          1.00          0.56        -0.03
# critic_score        0.56          1.00         0.41
# total_sales        -0.03          0.41         1.00

# %% [markdown]
# Продажи почти не зависят от отзывов пользователей, а вот на критиков можно посмотреть, хотя они тоже далеко не всегда верно определяют

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#
#         user_score	critic_score	total_sales
#         user_score	1.000000	0.557654	-0.031957
#         critic_score	0.557654	1.000000	0.406568
#         total_sales	-0.031957	0.406568	1.000000

# %%
new_data.loc[new_data["platform"]=="xone",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="critic_score",y="total_sales")
new_data.loc[new_data["platform"]=="xone",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="user_score",y="total_sales")
new_data.loc[new_data["platform"]=="xone",["user_score","critic_score","total_sales"]].corr()
# Out:
#               user_score  critic_score  total_sales
# user_score          1.00          0.47        -0.07
# critic_score        0.47          1.00         0.42
# total_sales        -0.07          0.42         1.00

# %% [markdown]
# У Xbox ситуация не сильно отличается.

# %%
new_data.loc[new_data["platform"]=="x360",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="critic_score",y="total_sales")
new_data.loc[new_data["platform"]=="x360",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="user_score",y="total_sales")
data.loc[data["platform"]=="x360",["user_score","critic_score","total_sales"]].corr()
# Out:
#               user_score  critic_score  total_sales
# user_score          1.00          0.62         0.11
# critic_score        0.62          1.00         0.39
# total_sales         0.11          0.39         1.00

# %%
data.loc[data["platform"]=="ps3",["user_score","critic_score","total_sales"]].corr()
new_data.loc[new_data["platform"]=="ps3",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="critic_score",y="total_sales")
new_data.loc[new_data["platform"]=="ps3",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="user_score",y="total_sales")
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='total_sales'>

# %% [markdown]
# Отзывы пользователей тоже мало на что влияют, но на критиков иногда можно посмотреть

# %%
data.loc[data["platform"]=="3ds",["user_score","critic_score","total_sales"]].corr()
new_data.loc[new_data["platform"]=="3ds",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="critic_score",y="total_sales")
new_data.loc[new_data["platform"]=="3ds",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="user_score",y="total_sales")
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='total_sales'>

# %%
data.loc[data["platform"]=="wiiu",["user_score","critic_score","total_sales"]].corr()
new_data.loc[new_data["platform"]=="wiiu",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="critic_score",y="total_sales")
new_data.loc[new_data["platform"]=="wiiu",["user_score","critic_score","total_sales"]].plot(kind="scatter",x="user_score",y="total_sales")
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='total_sales'>

# %% [markdown]
# Пользователи Nintendo внимательнее смотрят на отзывы. Продажи игр на консоли Nintendo зависят от отзывов критиков сильнее - игры с ОТЛИЧНЫМИ отзывами с большой вероятностью хорошо продаются. Но вообще отзывы не влияют на продажи

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Сравнение показателей на нескольких платформах, позволяет набрать вес твоему исследованию, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить парочку диаграмм рассеяния, коэф. корреляции отображает лишь возможное наличие линейной связи

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# ## Популярность жанров

# %% [markdown]
# ### Количество игр разных жанров

# %%
new_data.groupby("genre")["name"].count().sort_values().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='genre'>

# %%
new_data.groupby("genre")["name"].count().sort_values().plot(kind="barh")
plt.xlim(0,300)
# Out:
# (0.0, 300.0)

# %% [markdown]
# Большинство игр - экшен

# %% [markdown]
# ### Продажи разных жанров

# %%
cols = {}
for genre in new_data["genre"].unique():
    col = new_data.query("genre == @genre")["total_sales"].sort_values(ascending=False)
    cols[genre] = col

plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True
ax = pd.DataFrame(cols).sort_values(by=pd.DataFrame(cols).index[0],axis=1).plot(kind="box")
cmap = plt.get_cmap('hot')
plt.set_cmap(cmap)
plt.ylabel("Общие продажи")
ax
# Out:
# <AxesSubplot:ylabel='Общие продажи'>

# %%
ax = pd.DataFrame(cols).sort_values(by=pd.DataFrame(cols).index[0],axis=1).plot(kind="box",patch_artist=True)

plt.ylabel("Общие продажи")
plt.ylim(0,1.5)
plt.show()

# %% [markdown]
# #### Анализ жанров
# У жанра Экшн есть звезды, которые продаются отлично, но в среднем он продается на уровне большинства жанров. Очень хорошо продавшиеся игры есть у шутеров и РП. В среднем Шутеры - самые прибыльные, за ними идет спорт и платформеры.В стратегии, приключения и головоломки вкладываться не стоит.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Не стоит усложнять код

# %%
# check
new_data.boxplot(by="genre", column="total_sales");

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  При оформлении общего заголовка, мы сможем избавиться от служебной информации
#
# ![image-3.png](attachment:image-3.png)
#
#
# В статье и на рисунке представлен код, который поможет исправить общий заголовок
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит отсортировать значения для графика и развернуть график в горизонтальные бары, т.к. надписи названий длинные и не поместятся на оси х

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)
#
# Стоит нарисовать диаграммы размаха, пример ⬇⬇⬇
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %% [markdown]
# ## check

# %% [markdown]
# ## Портреты пользователей из разных рынков

# %%
#new_data.groupby("platform").sum()["na_sales"].sort_values(ascending=False).head(5).plot.pie( autopct='%1.1f%%')

# %%
#new_data.groupby("platform").sum()["eu_sales"].sort_values(ascending=False).head(5).plot.pie( autopct='%1.1f%%')

# %%
#new_data.groupby("platform").sum()["jp_sales"].sort_values(ascending=False).head(5).plot.pie( autopct='%1.1f%%')

# %%
# fig = plt.figure(figsize=(7, 4))

# ax1 = plt.subplot(1, 3, 1)
# new_data.groupby("platform").sum()["jp_sales"].sort_values(ascending=False).head(5).plot(kind = "pie",autopct='%1.1f%%',figsize=[20,20],title="Популярность платформ в Японии")
# ax2 = plt.subplot(1, 3, 2)
# new_data.groupby("platform").sum()["eu_sales"].sort_values(ascending=False).head(5).plot(kind = "pie",autopct='%1.1f%%',title="Популярность платформ в Северной Америке")
# ax3 = plt.subplot(1, 3, 3)
# new_data.groupby("platform").sum()["na_sales"].sort_values(ascending=False).head(5).plot(kind = "pie",autopct='%1.1f%%',title="Популярность платформ в Европе")

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка

# %% [markdown]
# Рынки европы и США очень похожи, но в Европе больше PS4. А вот рынок Японии сильно отличается - там доминирует Nintendo, после нее идет Sony, а Microsoft в топ 5 вообще нет. Очень популярны портативные консоли - 3ds, а также, провалившаяся во всем мире PSV, здесь есть в топ 5

# %% [markdown]
# ### check

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Предлагаю попробовать создать шестую категорию — «Другие» и объединить туда все не вошедшие в ТОП-5 строчки
#
# Добавил пример создания строки (у меня он развернут в обратном порядке)
#
#
# На данном этапе интересует сама выборка ТОП-5 плюс категория «Другие», без графиков

# %%
platform_data = new_data.groupby("platform",as_index=False).sum().loc[:,["platform","na_sales","eu_sales","jp_sales"]].sort_values(by="jp_sales",ascending=False)
platform_data_jp = platform_data[:6]
platform_data_jp=platform_data_jp.append({'platform': 'other', 'eu_sales': platform_data['eu_sales'].sum()-platform_data['eu_sales'][:6].sum(),
                  'jp_sales': platform_data['jp_sales'].sum()-platform_data['jp_sales'][:6].sum(),
                  'na_sales': platform_data['na_sales'].sum()-platform_data['na_sales'][:6].sum()}, ignore_index = True)
platform_data_jp = platform_data_jp[["platform","jp_sales"]]
platform_data_jp
# Out:
#   platform  jp_sales
# 0      3ds     67.81
# 1      ps3     23.35
# 2      psv     18.59
# 3      ps4     15.96
# 4     wiiu     10.88
# 5      psp      3.29
# 6    other      0.90

# %%
platform_data = platform_data.sort_values(by="eu_sales",ascending=False)
platform_data_eu = platform_data[:6]
platform_data_eu=platform_data_eu.append({'platform': 'other', 'eu_sales': platform_data['eu_sales'].sum()-platform_data['eu_sales'][:6].sum(),
                  'jp_sales': platform_data['jp_sales'].sum()-platform_data['jp_sales'][:6].sum(),
                  'na_sales': platform_data['na_sales'].sum()-platform_data['na_sales'][:6].sum()}, ignore_index = True)
platform_data_eu = platform_data_eu[["platform","eu_sales"]]
platform_data_eu
# Out:
#   platform  eu_sales
# 0      ps4    141.09
# 1      ps3     67.81
# 2     xone     51.59
# 3     x360     42.52
# 4      3ds     30.96
# 5       pc     25.61
# 6    other     32.90

# %%
platform_data = platform_data.sort_values(by="na_sales",ascending=False)
platform_data_na = platform_data[:6]
platform_data_na=platform_data_na.append({'platform': 'other', 'eu_sales': platform_data['eu_sales'].sum()-platform_data['eu_sales'][:6].sum(),
                  'jp_sales': platform_data['jp_sales'].sum()-platform_data['jp_sales'][:6].sum(),
                  'na_sales': platform_data['na_sales'].sum()-platform_data['na_sales'][:6].sum()}, ignore_index = True)
platform_data_na = platform_data_na[["platform","na_sales"]]
platform_data_na
# Out:
#   platform  na_sales
# 0      ps4    108.74
# 1     xone     93.12
# 2     x360     81.66
# 3      ps3     63.50
# 4      3ds     38.20
# 5     wiiu     29.21
# 6    other     23.34

# %%
# ax1 = plt.subplot(1, 3, 1)
# platform_data_jp.set_index(platform_data_jp["platform"]).plot(kind = "pie",y="jp_sales",autopct='%1.1f%%',title="Популярность платформ в Японии",legend=False)
# ax2 = plt.subplot(1, 3, 2)
# platform_data_na.set_index(platform_data_na["platform"]).plot(kind = "pie",y="na_sales",autopct='%1.1f%%',title="Популярность платформ в Японии",legend=False)
# ax3 = plt.subplot(1, 3, 3)
# platform_data_eu.set_index(platform_data_eu["platform"]).plot(kind = "pie",y="eu_sales",autopct='%1.1f%%',title="Популярность платформ в Японии",legend=False)

# %%
# fig = plt.figure(figsize=(7, 4))
# ax1 = plt.subplot(1, 3, 1)
# platform_data_jp.set_index(platform_data_jp["platform"])\
# .plot(kind = "pie",y="jp_sales",autopct='%1.1f%%',figsize=[5,5],title="Популярность платформ в Японии",legend=False)
# ax2 = plt.subplot(1, 3, 2)
# platform_data_na.set_index(platform_data_na["platform"])\
# .plot(kind = "pie",y="na_sales",autopct='%1.1f%%',figsize=[5,5],title="Популярность платформ в Японии",legend=False)
# ax3 = plt.subplot(1, 3, 3)
# platform_data_eu.set_index(platform_data_eu["platform"])\
# .plot(kind = "pie",y="eu_sales",autopct='%1.1f%%',figsize=[5,5],title="Популярность платформ в Японии",legend=False)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Самый простой пример ⬇⬇⬇

# %%
# check
import numpy as np

# пример из ссылки

# данные для линий

x = np.linspace(0, 5, 11)
y = x**2

# строим графики

plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')  #  Магия
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-');

# %%
# check
fig = plt.figure(figsize=(7, 4))

ax1 = plt.subplot(1, 3, 1)
ax2 = plt.subplot(1, 3, 2)
ax3 = plt.subplot(1, 3, 3)

platform_data_jp.set_index(platform_data_jp["platform"])\
.plot(ax = ax1, kind = "pie",y="jp_sales",autopct='%1.1f%%',figsize=[15,5],title="Популярность платформ в Японии",legend=False)

platform_data_na.set_index(platform_data_na["platform"])\
.plot(ax = ax2,  kind = "pie",y="na_sales",autopct='%1.1f%%',figsize=[15,5],title="Популярность платформ в Японии",legend=False)

platform_data_eu.set_index(platform_data_eu["platform"])\
.plot(ax = ax3,  kind = "pie",y="eu_sales",autopct='%1.1f%%',figsize=[15,5],title="Популярность платформ в Японии",legend=False)
# Out:
# <AxesSubplot:title={'center':'Популярность платформ в Японии'}, ylabel='eu_sales'>

# %%
# check
# import pandas as pd
df_app = pd.DataFrame([['ps',1,2,3],
                   ['xone',3,5,6],
                   ['pc',8,9,10],
                   ['ps3',1,7,3],
                   ['ps4',5,2,3]], columns=['platform', 'eu','jp','na'])
display(df_app)

df_other = df_app[3:]
df_other = df_other.append({'platform': 'Other', 'eu': df_app['eu'].sum()-df_app['eu'][3:].sum(),
                  'jp': df_app['jp'].sum()-df_app['jp'][3:].sum(),
                  'na': df_app['na'].sum()-df_app['na'][3:].sum()}, ignore_index = True)
df_other
# Out:
#   platform  eu  jp  na
# 0       ps   1   2   3
# 1     xone   3   5   6
# 2       pc   8   9  10
# 3      ps3   1   7   3
# 4      ps4   5   2   3
#   platform  eu  jp  na
# 0      ps3   1   7   3
# 1      ps4   5   2   3
# 2    Other  12  16  19

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Или берем одну выборку ⬇⬇⬇ и создаем из неё выборку с 6-ю строчками.
#
# Это базовый навык работы с таблицей, навык по трансформации — из 9-ти строчек получить 6 в которой первые пять это топовые позиции, а последняя шестая — это сумма всех остальных строк, кроме первых пяти
#
# ![image.png](attachment:image.png)
#
# Если ты не понимаешь, как выполнить это, тогда стоит задать вопрос преподавателю по проектам в чате «пачки». Также ты можешь написать вопрос или пример кода в проекте и опять отправить его на проверку — так я смогу тебе ответить
#
#
# Можно посмотреть на порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948
#
# https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79 (ссылка может не работать)
#
# https://www.marsja.se/how-to-use-iloc-and-loc-for-indexing-and-slicing-pandas-dataframes/
#
#
# Выбор способа создания за тобой

# %%
# check

new_data.groupby('platform').agg({'na_sales': 'sum'}).sort_values(by='na_sales', ascending=False)
# Out:
#           na_sales
# platform
# ps4         108.74
# xone         93.12
# x360         81.66
# ps3          63.50
# 3ds          38.20
# wiiu         29.21
# pc           11.17
# wii           6.56
# psv           5.04
# ds            0.57
# psp           0.00

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы
#
# Стоит оформить графики раздела TOП-5:
#
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#  + круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %%
genre_data = new_data.groupby("genre",as_index=False).sum().loc[:,["genre","na_sales","eu_sales","jp_sales"]].sort_values(by="jp_sales",ascending=False)
genre_data_jp = genre_data[:6]
genre_data_jp=genre_data_jp.append({'genre': 'other', 'eu_sales': genre_data['eu_sales'].sum()-genre_data['eu_sales'][:6].sum(),
                  'jp_sales': genre_data['jp_sales'].sum()-genre_data['jp_sales'][:6].sum(),
                  'na_sales': genre_data['na_sales'].sum()-genre_data['na_sales'][:6].sum()}, ignore_index = True)
genre_data_jp = genre_data_jp[["genre","jp_sales"]]
genre_data_jp
# Out:
#           genre  jp_sales
# 0  role-playing     51.04
# 1        action     40.49
# 2          misc      9.20
# 3      fighting      7.65
# 4       shooter      6.61
# 5     adventure      5.82
# 6         other     19.97

# %%
genre_data = genre_data.sort_values(by="eu_sales",ascending=False)
genre_data_eu = genre_data[:6]
genre_data_eu=genre_data_eu.append({'genre': 'other', 'eu_sales': genre_data['eu_sales'].sum()-genre_data['eu_sales'][:6].sum(),
                  'jp_sales': genre_data['jp_sales'].sum()-genre_data['jp_sales'][:6].sum(),
                  'na_sales': genre_data['na_sales'].sum()-genre_data['na_sales'][:6].sum()}, ignore_index = True)
genre_data_eu = genre_data_eu[["genre","eu_sales"]]
genre_data_eu
# Out:
#           genre  eu_sales
# 0        action    118.38
# 1       shooter     87.86
# 2        sports     60.52
# 3  role-playing     36.97
# 4        racing     20.19
# 5          misc     20.04
# 6         other     48.52

# %%
genre_data = genre_data.sort_values(by="eu_sales",ascending=False)
genre_data_na = genre_data[:6]
genre_data_na=genre_data_na.append({'genre': 'other', 'eu_sales': genre_data['eu_sales'].sum()-genre_data['eu_sales'][:6].sum(),
                  'jp_sales': genre_data['jp_sales'].sum()-genre_data['jp_sales'][:6].sum(),
                  'na_sales': genre_data['na_sales'].sum()-genre_data['na_sales'][:6].sum()}, ignore_index = True)
genre_data_na = genre_data_na[["genre","na_sales"]]
genre_data_na
# Out:
#           genre  na_sales
# 0        action    126.11
# 1       shooter    109.74
# 2        sports     65.27
# 3  role-playing     46.40
# 4        racing     12.96
# 5          misc     27.49
# 6         other     49.80

# %%
#new_data.groupby("genre").sum()["na_sales"].sort_values(ascending=False).head(5).plot.pie( autopct='%1.1f%%')

# %%
#new_data.groupby("genre").sum()["eu_sales"].sort_values(ascending=False).head(5).plot.pie( autopct='%1.1f%%')

# %%
#new_data.groupby("genre").sum()["jp_sales"].sort_values(ascending=False).head(5).plot.pie( autopct='%1.1f%%')

# %% [markdown]
# Рынки США и Европы похожи - единственная разница в Европе на 5 месте гонки, в США - смешанное. Лучше всего продаются шутеры и экшн. Япония сильно отличается - там популярны ролевые игры и экшн, а шутеры на 5 месте.

# %%
new_data.groupby("rating").sum()["na_sales"].sort_values(ascending=False).plot.pie( autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='na_sales'>

# %%
new_data.groupby("rating").sum()["eu_sales"].sort_values(ascending=False).plot.pie( autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='eu_sales'>

# %%
new_data.groupby("rating").sum()["jp_sales"].sort_values(ascending=False).plot.pie( autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='jp_sales'>

# %%
# check
fig = plt.figure(figsize=(7, 4))

ax1 = plt.subplot(1, 3, 1)
ax2 = plt.subplot(1, 3, 2)
ax3 = plt.subplot(1, 3, 3)

new_data.groupby("rating").sum()["jp_sales"].sort_values(ascending=False)\
.plot(ax = ax1, kind = "pie",y="jp_sales",autopct='%1.1f%%',figsize=[15,5],title="Популярность платформ в Японии",legend=False)

new_data.groupby("rating").sum()["eu_sales"].sort_values(ascending=False)\
.plot(ax = ax2,  kind = "pie",y="na_sales",autopct='%1.1f%%',figsize=[15,5],title="Популярность платформ в Японии",legend=False)

new_data.groupby("rating").sum()["na_sales"].sort_values(ascending=False)\
.plot(ax = ax3,  kind = "pie",y="eu_sales",autopct='%1.1f%%',figsize=[15,5],title="Популярность платформ в Японии",legend=False)
# Out:
# <AxesSubplot:title={'center':'Популярность платформ в Японии'}, ylabel='na_sales'>

# %%
new_data.loc[new_data["rating"]=="na",:].sort_values(by="jp_sales",ascending=False).head(10)
# Out:
#                                           name platform  year_of_release  \
# 33                         pokemon x/pokemon y      3ds           2013.0
# 385                           monster hunter 4      3ds           2013.0
# 412                  yokai watch 2 ganso/honke      3ds           2014.0
# 47   pokemon omega ruby/pokemon alpha sapphire      3ds           2014.0
# 406                           monster hunter x      3ds           2015.0
# 563                     yokai watch 2 shinuchi      3ds           2014.0
# 96         super smash bros. for wii u and 3ds      3ds           2014.0
# 694                        yokai watch busters      3ds           2015.0
# 108                           pokemon sun/moon      3ds           2016.0
# 184                             tomodachi life      3ds           2013.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 33   role-playing      5.28      4.19      4.35         0.78           NaN
# ...

# %% [markdown]
# лучше всего продаются игры с рейтингом М (сказывается популярность шутеров ), но много игр с неопределенным рейтингом, даже в США, где и работает ESRB. Нужно что то делать со способом сбора данных.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %%
new_data["n_rating"] = new_data["rating"].replace({"e":0,"e10+":10,"t":13,"m":17,"na":100})
new_data.head(5)
# Out:
# /tmp/ipykernel_1117/3170601006.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["n_rating"] = new_data["rating"].replace({"e":0,"e10+":10,"t":13,"m":17,"na":100})
#                          name platform  year_of_release         genre  \
# 16         grand theft auto v      ps3           2013.0        action
# 23         grand theft auto v     x360           2013.0        action
# 31  call of duty: black ops 3      ps4           2015.0       shooter
# 33        pokemon x/pokemon y      3ds           2013.0  role-playing
# 42         grand theft auto v      ps4           2014.0        action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
new_data.plot(kind="scatter",x="n_rating",y="na_sales")
new_data.loc[:,["n_rating","na_sales"]].corr()
# Out:
#           n_rating  na_sales
# n_rating      1.00     -0.16
# na_sales     -0.16      1.00

# %%
new_data.plot(kind="scatter",x="n_rating",y="eu_sales")
new_data.loc[:,["n_rating","eu_sales"]].corr()
# Out:
#           n_rating  eu_sales
# n_rating      1.00     -0.16
# eu_sales     -0.16      1.00

# %%
new_data.plot(kind="scatter",x="n_rating",y="jp_sales")
new_data.loc[:,["n_rating","jp_sales"]].corr()
# Out:
#           n_rating  jp_sales
# n_rating      1.00      0.09
# jp_sales      0.09      1.00

# %% [markdown]
# Рейтинг слабо влияет на продажи игр

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Интересное исследование, молодец

# %%
new_data = new_data.dropna(subset=["user_score"])
new_data.loc[new_data["platform"] == "XOne","user_score"].count()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Срез стоит подправить. Имеются строки, где нет оценки критиков, но есть оценка юзеров. Срезая все сразу, мы теряем эти строки.
#
#         new_data = new_data.dropna()
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %%
new_data.loc[new_data["platform"] == "PC","user_score"].count()
# Out:
# 0

# %% [markdown]
# ## check

# %% [markdown]
# ## Проверки гипотез

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги на XOne и PC равны.
# Альтернативная гипотеза: Средние пользовательские рейтинги на XOne и PC НЕ равны.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1193 entries, 16 to 16692
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1193 non-null   object
#  1   platform         1193 non-null   object
#  2   year_of_release  1193 non-null   float64
#  3   genre            1193 non-null   object
#  4   na_sales         1193 non-null   float64
#  5   eu_sales         1193 non-null   float64
#  6   jp_sales         1193 non-null   float64
#  7   other_sales      1193 non-null   float64
#  8   critic_score     977 non-null    float64
#  9   user_score       1193 non-null   float64
#  10  rating           1193 non-null   object
#  11  total_sales      1193 non-null   float64
#  12  n_rating         1193 non-null   int64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 130.5+ KB

# %%
alpha = 0.05 # уровень статистической значимости

results = st.ttest_ind(
    new_data.loc[new_data["platform"] == "xone","user_score"],#.iloc[0:134], 
     new_data.loc[new_data["platform"] == "pc","user_score"],
      alternative='two-sided')

print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.16390354211387628
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> В стат тесте не обязательно выравнивать кол-во оценок
#
#         в жизни, практически всегда одна из выборок будет меньше

# %% [markdown]
# Рейтинги игр на ПК и Xbox недостаточно отличаются,чтобы сказать, что они сильно разные. (вероятность 0.16 получить одинаковые числа случайно - слишком большая для этого)

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.25589454518869065

# %% [markdown]
# Точно, это вероятность получить одинаковые значения. Одинаковые отзывы в 25% случаев так себе одинаковые, поменял алфа на 0.5

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Если поменять альфу на
#
#         поменял алфа на 0.5
#
# мы отвергнем каждый второй более или менее удачный для бизнеса эксперимент, это будет очень затратно и приведет к ухудшению позиции компании на рынке ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> С вероятностью около 20% различие в средних оценках для исследуемых платформ мы получим случайно. Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними оценками

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть почти никогда :)  (но учитываем, что тест проводится на выборке из генеральной совокупности, все может поменяться)

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») Одинаковые.
# Альтернативная: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно, для акцентирования можно использовать в нулевой гипотезе слово равны

# %%
new_data.loc[new_data["genre"] == "Action","user_score"].count()
# Out:
# 0

# %%
new_data.loc[new_data["genre"] == "Sports","user_score"].count()
# Out:
# 0

# %%
alpha = 0.05 # уровень статистической значимости

results = st.ttest_ind(
    new_data.loc[new_data["genre"] == "action","user_score"].iloc[0:106], 
     new_data.loc[new_data["genre"] == "sports","user_score"],
      alternative='two-sided')

print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) '
    'и Sports (англ. «спортивные соревнования») Одинаковые.')
# Out:
# p-значение: 1.872435578173971e-18
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# ### Расшифровка p-value на тест 2
# Шанс случайно получить одинаковые значения для оценок игр жанра Action и Sports слишком мал, чтобы считать что они одинаковые, поэтому нулевая гипотеза отвергается.

# %% [markdown]
# Нулевая гипотеза всегда со знаком равенста. В данном случае подходили двусторонние альтернативные гипотезы - мы просто смотрели равны рейтинги или нет. Критерий - одинаковый размер данных, так точнее

# %% [markdown]
# ## check

# %% [markdown]
# ## Вывод

# %% [markdown]
# Очистил данные от пропусков - ESRB заменил, года в основном удалил так как было мало продаж и строк. Рассмотрел актуальность платформ, рейтингов и жанров. Проверил зависимость продаж от отзывов и рейтингов, проверил гипотезы.
#     **Вывод**: после очистки данных от пропусков и дубликатов, выяснил актуальные платформы - для рынков Европы и Северной Америки - XOne и PS4 для Японии 3ds, PS4. Эти платформы появились не так давно и их актуальность и продажи только растут, либо продажи падают, но все еще очень высоки и в 2017 на них можно заработать. Жанры - В Европе и Северной Америке популярны Шутеры, Экшн и Спорт. В Японии - Ролевые игры, Экшн. Рейтинг не влияет на продажи

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Итоговый вывод технически составлен грамотно, самое главное — сформирована итоговая рекомендация бизнесу, молодец
#
# стоит немного наполнить вывод подробностями выполнения самого проекта

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить название
#  + заполнение пропусков в колонке год выпуска
#  + добавить оформление проекту — заголовки разделов
#  + переименование
#  + обработать пропуски и сократить категории в рейтингах ESRB — на твое усмотрение
#  + выполнить проверку на дублирование записей
#  + дополнить перечень перспективных платформ
#  + исправить диаграмму размаха для анализа продаж на актуальных платформах
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
# Цветовая гамма не подбиралась специально под платформы, кому-что попадется, 😉      
      
    labels_c=sales.platform
    colours = {'Wii':'C60', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'lightsteelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'Fuchsia', '2600':'C15', 'PSP':'C48', 
               'XOne':'LimeGreen',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2013

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])
